# %%
import pandas as pd
import deepchem as dc
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 import deepchem as dc
#
# File ~/miniforge3/lib/python3.9/site-packages/deepchem/__init__.py:10, in <module>
#       8 import deepchem.data
#       9 import deepchem.feat
# ---> 10 import deepchem.hyper
#      11 import deepchem.metalearning
#      12 import deepchem.metrics
#
# File ~/miniforge3/lib/python3.9/site-packages/deepchem/hyper/__init__.py:2, in <module>
#       1 # flake8: noqa
# ----> 2 from deepchem.hyper.base_classes import HyperparamOpt
#       3 from deepchem.hyper.grid_search import GridHyperparamOpt
#       4 from deepchem.hyper.gaussian_process import GaussianProcessHyperparamOpt
#
# File ~/miniforge3/lib/python3.9/site-packages/deepchem/hyper/base_classes.py:6, in <module>
#       4 from deepchem.data import Dataset
# ...
